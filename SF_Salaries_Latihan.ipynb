# %% [markdown]
# ___
#
# <a href='https://www.purwadhika.com/'> <img style="height: 200px" src='https://www.dicoding.com/images/original/event/201705181703334cc2c00c0d639e4593a12a55aa4c8103.png' /></a>
# ___

# %% [markdown]
# # SF Salaries Exercise
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# ** Import pandas as pd.**

# %%
import pandas as pd

# %% [markdown]
# ** Read Salaries.csv as a dataframe called sal.**

# %%
df = pd.read_csv('Salaries.csv')

# %% [markdown]
# ** Check the head of the DataFrame. **

# %%
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay ?**

# %%
# Out:
# 66325.44884050643

# %% [markdown]
# ** What is the highest amount of OvertimePay in the dataset ? **

# %%
# Out:
# 245131.88

# %% [markdown]
# ** What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll). **

# %%
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ** What is the name of highest paid person (including benefits)?**

# %%
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %% [markdown]
# ** What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %% [markdown]
# ** What was the average (mean) BasePay of all employees per year? (2011-2014) ? **

# %%
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ** How many unique job titles are there? **

# %%
# Out:
# 2159

# %% [markdown]
# ** What are the top 5 most common jobs? **

# %%
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# ** How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?) **

# %%
# Out:
# 202

# %% [markdown]
# ** How many people have the word Chief in their job title? (This is pretty tricky) **

# %%
len(df[df['JobTitle'].apply(lambda x : 'chief' in x.lower())])
# Out:
# 627

# %%
# Out:
# 477

# %% [markdown]
# ** Bonus: Is there a correlation between length of the Job Title string and Salary? **

# %%
df['titel_len']=df['JobTitle'].str.len()

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status  titel_len
# 0  2011    NaN  San Francisco     NaN         46
# 1  2011    NaN  San Francisco     NaN         31
# 2  2011    NaN  San Francisco     NaN         31
# 3  2011    NaN  San Francisco     NaN         36
# 4  2011    NaN  San Francisco     NaN         44

# %%
df[['titel_len','TotalPayBenefits']].corr()
# Out:
#                   titel_len  TotalPayBenefits
# titel_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000

# %%
# Out:
#                   title_len  TotalPayBenefits
# title_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000

# %%
df.loc[df['JobTitle'].str.upper().str.contains('MANAGER')]
# Out:
#             Id              EmployeeName  \
# 0            1            NATHANIEL FORD
# 83          84            EDWARD REISKIN
# 87          88               KEVIN BARRY
# 95          96              MIVIC HIROSE
# 162        163             JULIE LABONTE
# 168        169          AMPARO RODRIGUEZ
# 177        178              HARVEY ELWIN
# 182        183          SUSAN BUCHBINDER
# 185        186                JOHN BROWN
# 203        204          ROSELYN JEQUINTO
# 395       NaN  San Francisco     NaN         12
# 406       NaN  San Francisco     NaN         13
# 417       NaN  San Francisco     NaN         13
# 426       NaN  San Francisco     NaN         13
# 428       NaN  San Francisco     NaN         13
# 430       NaN  San Francisco     NaN         12
# 441       NaN  San Francisco     NaN         13
# 442       NaN  San Francisco     NaN         13
# 445       NaN  San Francisco     NaN         13
# 450       NaN  San Francisco     NaN         10
# 462       NaN  San Francisco     NaN         12
# ...       ...            ...     ...        ...
# 142324    NaN  San Francisco     NaN         10
# 142382    NaN  San Francisco     NaN          9
# 142440    NaN  San Francisco     NaN         17
# 142558    NaN  San Francisco     NaN         10
# 142614    NaN  San Francisco     NaN         15
# 142899    NaN  San Francisco     NaN         10
# 143232    NaN  San Francisco     NaN         17
# 143627    NaN  San Francisco     NaN         15
# 143685    NaN  San Francisco     NaN         17
# 143725    NaN  San Francisco     NaN          9
# 144051    NaN  San Francisco     NaN         10
# 144134    NaN  San Francisco     NaN         10
# 144139    NaN  San Francisco     NaN          9
# 144608    NaN  San Francisco     NaN         17
# 145023    NaN  San Francisco     NaN         10
# 145090    NaN  San Francisco     NaN          9
# 145158    NaN  San Francisco     NaN         13
# 145306    NaN  San Francisco     NaN         10
# 145784    NaN  San Francisco     NaN         10
# 145914    NaN  San Francisco     NaN         10
# 146263    NaN  San Francisco     NaN         24
# 146490    NaN  San Francisco     NaN         12
# 146669    NaN  San Francisco     NaN         10
# 146670    NaN  San Francisco     NaN         10
# 146674    NaN  San Francisco     NaN         11
# 147216    NaN  San Francisco     NaN         11
# 147502    NaN  San Francisco     NaN         10
# 147805    NaN  San Francisco     NaN         10
# 148150    NaN  San Francisco     NaN         21
# 148475    NaN  San Francisco     NaN         10
#
# [4110 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 14 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# titel_len           148654 non-null int64
# dtypes: float64(8), int64(3), object(3)
# memory usage: 15.9+ MB

# %% [markdown]
# # Great Job!

# %%
df['Notes']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
#           ..
# 148624   NaN
# 148625   NaN
# 148626   NaN
# 148627   NaN
# 148628   NaN
# 148629   NaN
# 148630   NaN
# 148631   NaN
# 148632   NaN
# 148633   NaN
# 148634   NaN
# 148635   NaN
# 148636   NaN
# 148637   NaN
# 148638   NaN
# 148639   NaN
# 148640   NaN
# 148641   NaN
# 148642   NaN
# 148643   NaN
# 148644   NaN
# 148645   NaN
# 148646   NaN
# 148647   NaN
# 148648   NaN
# 148649   NaN
# 148650   NaN
# 148651   NaN
# 148652   NaN
# 148653   NaN
# Name: Notes, Length: 148654, dtype: float64

# %%
df_tmp.loc[df_tmp['A']==1,'B']=7
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d0d9822386e3> in <module>
# ----> 1 df_tmp.loc[df_tmp['A']==1,'B']=7
#
# NameError: name 'df_tmp' is not defined

# %%
df_tmp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-d7ca9ac62666> in <module>
# ----> 1 df_tmp
#
# NameError: name 'df_tmp' is not defined
